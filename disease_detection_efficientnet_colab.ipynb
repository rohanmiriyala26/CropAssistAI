import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from concurrent.futures import ProcessPoolExecutor

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchinfo import summary
from torchvision import transforms, models, datasets
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

from sklearn.metrics import recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.preprocessing import label_binarize

# %%
from google.colab import drive
drive.mount("/content/drive")

corrupted = []
df_list = []

root_dir = '/content/combined_dataset'

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
import shutil

# Path ke direktori dataset Train dan Validation
train_dir = '/content/drive/MyDrive/20k-multi-class-crop-disease-images/Train'
validation_dir = '/content/drive/MyDrive/20k-multi-class-crop-disease-images/Validation'

# Folder tujuan untuk menyimpan semua gambar gabungan
destination_base_folder = '/content/combined_dataset'

# Buat folder tujuan jika belum ada
os.makedirs(destination_base_folder, exist_ok=True)

# Fungsi untuk membaca gambar dari direktori dan menyalinnya ke folder tujuan dengan struktur yang sama
def copy_files_with_structure(source_directory, destination_base_folder):
    for root, dirs, files in os.walk(source_directory):
        for file in files:
            if file.endswith(('png', 'jpg', 'jpeg')):  # Filter file gambar
                source_file_path = os.path.join(root, file)
                relative_path = os.path.relpath(root, source_directory)
                destination_folder = os.path.join(destination_base_folder, relative_path)
                destination_file_path = os.path.join(destination_folder, file)
                
                # Buat folder tujuan jika belum ada
                os.makedirs(destination_folder, exist_ok=True)
                
                # Salin file
                shutil.copy2(source_file_path, destination_file_path)
                print(f"File {file} berhasil disalin ke {destination_file_path}.")

# Salin gambar dari folder Train dan Validation ke folder tujuan dengan struktur yang sama
copy_files_with_structure(train_dir, destination_base_folder)
copy_files_with_structure(validation_dir, destination_base_folder)
# Out:
# File bact116.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact116.jpg.
# File bact147.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact147.png.
# File bact94.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact94.jpg.
# File bact80.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact80.jpg.
# File bact202.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact202.png.
# File bact195.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact195.jpg.
# File bact429.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact429.jpg.
# File bact151.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact151.png.
# File bact237.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact237.jpg.
# File bact354.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact354.png.
# File 20.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/20.jpg.
# File bact113.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact113.jpg.
# File bact339.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact339.jpg.
# File bact242.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact242.jpg.
# File bact381.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact381.png.
# File 6.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/6.jpg.
# File bact212.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact212.jpg.
# File bact245.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact245.jpg.
# File bact367.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact367.jpg.
# File bact335.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact335.jpg.
# File bact133.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact133.png.
# File bact162.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact162.jpg.
# File bact436.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact436.jpg.
# File bact332.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact332.jpg.
# File bact211.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact211.jpg.
# File bact293.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact293.jpg.
# File bact169.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact169.jpg.
# File bact197.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact197.jpg.
# File bact51.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact51.png.
# File 5.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/5.jpg.
# File bact239.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact239.jpg.
# File bact241.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact241.jpg.
# File 8.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/8.jpg.
# File bact378.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact378.png.
# File bact352.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact352.png.
# File P1010086jpg.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/P1010086jpg.jpg.
# File bact251.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact251.png.
# File bact163.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact163.jpg.
# File bact28.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact28.jpg.
# File bact36.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact36.jpg.
# File bact136.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact136.png.
# File bact18.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact18.jpg.
# File bact360.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact360.jpg.
# File bact95.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact95.jpg.
# File bact384.png berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/bact384.png.
# File bact13.jpg berhasil disalin ke /kaggle/working/combined_dataset/bacterial_blight in Cotton/b
jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/24.jpg.
# File redrot (48).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (48).jpeg.
# File 64.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/64.jpg.
# File redrot (68).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (68).jpeg.
# File redrot (9).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (9).jpeg.
# File redrot (6).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (6).jpeg.
# File 31.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/31.jpg.
# File redrot (20).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (20).jpeg.
# File 43.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/43.jpg.
# File 13.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/13.jpg.
# File 74.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/74.jpg.
# File redrot (12).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (12).jpeg.
# File redrot (51).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (51).jpeg.
# File 68.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/68.jpg.
# File redrot (52).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (52).jpeg.
# File 53.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/53.jpg.
# File redrot (2).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (2).jpeg.
# File redrot (53).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (53).jpeg.
# File redrot (44).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (44).jpeg.
# File redrot (36).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (36).jpeg.
# File redrot (23).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (23).jpeg.
# File 72.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/72.jpg.
# File redrot (38).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (38).jpeg.
# File 32.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/32.jpg.
# File redrot (17).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (17).jpeg.
# File 17.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/17.jpg.
# File 26.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/26.jpg.
# File 39.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/39.jpg.
# File redrot (5).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (5).jpeg.
# File 15.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/15.jpg.
# File 12.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/12.jpg.
# File redrot (64).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (64).jpeg.
# File redrot (18).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (18).jpeg.
# File 11.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/11.jpg.
# File 70.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/70.jpg.
# File redrot (47).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (47).jpeg.
# File redrot (45).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (45).jpeg.
# File redrot (28).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (28).jpeg.
# File 34.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/34.jpg.
# File 27.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/27.jpg.
# File redrot (46).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (46).jpeg.
# File 51.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/51.jpg.
# File 52.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/52.jpg.
# File 21.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/21.jpg.
# File 4.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/4.jpg.
# File redrot (19).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (19).jpeg.
# File redrot (1).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (1).jpeg.
# File redrot (13).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (13).jpeg.
# File 3.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/3.jpg.
# File 36.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/36.jpg.
# File redrot (26).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (26).jpeg.
# File redrot (55).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (55).jpeg.
# File redrot (15).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (15).jpeg.
# File redrot (11).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (11).jpeg.
# File redrot (516).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (516).jpeg.
# File 63.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/63.jpg.
# File 19.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/19.jpg.
# File 47.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/47.jpg.
# File redrot (21).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (21).jpeg.
# File redrot (56).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (56).jpeg.
# File 14.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/14.jpg.
# File redrot (73).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (73).jpeg.
# File 18.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/18.jpg.
# File redrot (31).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (31).jpeg.
# File redrot (49).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (49).jpeg.
# File redrot (4).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (4).jpeg.
# File 49.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/49.jpg.
# File redrot (74).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (74).jpeg.
# File redrot (33).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (33).jpeg.
# File redrot (66).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (66).jpeg.
# File 66.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/66.jpg.
# File redrot (71).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (71).jpeg.
# File redrot (69).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (69).jpeg.
# File redrot (29).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (29).jpeg.
# File redrot (59).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (59).jpeg.
# File redrot (60).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (60).jpeg.
# File 25.jpg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/25.jpg.
# File redrot (65).jpeg berhasil disalin ke /kaggle/working/combined_dataset/RedRot sugarcane/redrot (65).jpeg.
# File Corn_Gray_Spot (11).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (11).jpg.
# File Corn_Gray_Spot (3).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (3).jpg.
# File Corn_Gray_Spot (13).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (13).jpg.
# File Corn_Gray_Spot (14).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (14).jpg.
# File Corn_Gray_Spot (8).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (8).jpg.
# File Corn_Gray_Spot (5).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (5).jpg.
# File Corn_Gray_Spot (10).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (10).jpg.
# File Corn_Gray_Spot (2).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (2).jpg.
# File Corn_Gray_Spot (6).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (6).jpg.
# File Corn_Gray_Spot (18).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (18).jpg.
# File Corn_Gray_Spot (7).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (7).jpg.
# File Corn_Gray_Spot (15).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (15).jpg.
# File Corn_Gray_Spot (12).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (12).jpg.
# File Corn_Gray_Spot (20).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (20).jpg.
# File Corn_Gray_Spot (4).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (4).jpg.
# File Corn_Gray_Spot (1).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (1).jpg.
# File Corn_Gray_Spot (19).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (19).jpg.
# File Corn_Gray_Spot (17).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (17).jpg.
# File Corn_Gray_Spot (16).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (16).jpg.
# File Corn_Gray_Spot (9).jpg berhasil disalin ke /kaggle/working/combined_dataset/Gray_Leaf_Spot/Corn_Gray_Spot (9).jpg.
# File 00001504.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001504.jpg.
# File 00001488.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001488.jpg.
# File 00001412.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001412.jpg.
# File 00001303.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001303.jpg.
# File 00001312.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001312.jpg.
# File 00001475.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001475.jpg.
# File 00001374.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001374.jpg.
# File 00001262.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001262.jpg.
# File 00001469.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001469.jpg.
# File 00001360.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001360.jpg.
# File 00001411.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001411.jpg.
# File 00001467.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001467.jpg.
# File 00001256.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001256.jpg.
# File 00001465.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001465.jpg.
# File 00001249.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001249.jpg.
# File 00001355.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001355.jpg.
# File 00001287.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001287.jpg.
# File 00001457.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001457.jpg.
# File 00001275.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001275.jpg.
# File 00001254.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001254.jpg.
# File 00001292.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001292.jpg.
# File 00001252.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001252.jpg.
# File 00001326.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001326.jpg.
# File 00001434.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001434.jpg.
# File 00001268.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001268.jpg.
# File 00001316.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001316.jpg.
# File 00001407.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001407.jpg.
# File 00001376.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001376.jpg.
# File 00001397.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001397.jpg.
# File 00001300.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001300.jpg.
# File 00001294.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001294.jpg.
# File 00001432.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001432.jpg.
# File 00001318.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001318.jpg.
# File 00001514.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001514.jpg.
# File 00001285.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001285.jpg.
# File 00001440.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001440.jpg.
# File 00001439.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001439.jpg.
# File 00001322.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001322.jpg.
# File 00001409.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001409.jpg.
# File 00001450.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001450.jpg.
# File 00001446.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001446.jpg.
# File 00001377.jpg berhasil disalin ke /kaggle/working/combined_dataset/Wheat powdery mildew/00001377.jpg.

# %%
from google.colab import drive
drive.mount("/content/drive")

def process_image(image_path, animal):
    if not os.path.isfile(image_path):
        return [image_path, True, None, None, None, None, None, animal]

    img = cv2.imread(image_path)
    if img is None:
        return [image_path, True, None, None, None, None, None, animal]

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_pil = Image.fromarray(img_rgb)
    img_hash = imagehash.phash(img_pil)
    width, height, channels = img.shape
    image_format = os.path.splitext(image_path)[-1]

    return [image_path, False, img_hash, image_format, width, height, channels, animal]

# %%
from google.colab import drive
drive.mount("/content/drive")

def process_animal(animal_dir, animal):
    image_paths = [os.path.join(animal_dir, image) for image in os.listdir(animal_dir) if os.path.isfile(os.path.join(animal_dir, image))]

    with ProcessPoolExecutor() as executor:
        results = executor.map(process_image, image_paths, [animal] * len(image_paths))

    valid_results = []
    for result in results:
        if result:
            if result[1]:
                corrupted.append(result[0])
            valid_results.append(result)
    return valid_results

# %%
from google.colab import drive
drive.mount("/content/drive")

for animal in os.listdir(root_dir):
    animal_dir = os.path.join(root_dir, animal)
    if os.path.isdir(animal_dir):
        results = process_animal(animal_dir, animal)
        df_list.extend(results)
# Out:
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# libpng warning: iCCP: profile 'ICC Profile': 0h: PCS illuminant is not D50
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: cHRM chunk does not match sRGB
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: cHRM chunk does not match sRGB
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: cHRM chunk does not match sRGB

# %%
from google.colab import drive
drive.mount("/content/drive")

print(f'Total corrupted images: {len(corrupted)}\n'
      f'Corrupted Images:\n{corrupted}')
# Out:
# Total corrupted images: 0
# Corrupted Images:
# []

# %%
from google.colab import drive
drive.mount("/content/drive")

df = pd.DataFrame(columns=['image_path', 'corrupted', 'image_hash', 'image_format', 'width', 'height', 'channels', 'label'], data = df_list)
df.head()
# Out:
#                                           image_path  corrupted  \
# 0  /kaggle/working/combined_dataset/Wheat aphid/2...      False
# 1  /kaggle/working/combined_dataset/Wheat aphid/2...      False
# 2  /kaggle/working/combined_dataset/Wheat aphid/2...      False
# 3  /kaggle/working/combined_dataset/Wheat aphid/2...      False
# 4  /kaggle/working/combined_dataset/Wheat aphid/1...      False
#
#          image_hash image_format  width  height  channels        label
# 0  ff3f4f466340301c         .jpg    220     185         3  Wheat aphid
# 1  d55157ce6a3213cc         .jpg    529     480         3  Wheat aphid
# 2  c189975b7396c5a8         .jpg    488     732         3  Wheat aphid
# 3  b3988ec58dc5455e         .jpg    355     600         3  Wheat aphid
# 4  a7a5e989a8cb01db         .jpg    482     412         3  Wheat aphid

# %%
from google.colab import drive
drive.mount("/content/drive")

df.describe().loc[['mean', 'std', 'min', 'max']]
# Out:
#             width       height  channels
# mean   490.144291   479.341609       3.0
# std    412.816607   417.908929       0.0
# min     31.000000    36.000000       3.0
# max   5504.000000  8256.000000       3.0

# %%
from google.colab import drive
drive.mount("/content/drive")

df['image_format'].value_counts().plot(kind='bar', title='Number of images per format')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, '.jpg'), Text(1, 0, '.jpeg'), Text(2, 0, '.png')])

# %%
from google.colab import drive
drive.mount("/content/drive")

class CONFIG:
    IMAGE_HEIGHT = 224
    IMAGE_WIDTH = 224
    CHANNELS = 3

    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    N_CLASSES = df['label'].nunique()
    
    BATCH_SIZE = 16
    N_EPOCHS = 50
    PATIENCE_EPOCHS = 10
    LR = 0.001
    L2 = 0.0001
    DROPOUT = 0.3

    PATIENCE_SCHEDULER = 5

    MIN_VALUE_ACCURACY = 80

# %%
from google.colab import drive
drive.mount("/content/drive")

transform = transforms.Compose([
    transforms.Resize((CONFIG.IMAGE_HEIGHT, CONFIG.IMAGE_WIDTH)),
    transforms.ToTensor(),
    transforms.ColorJitter(brightness=0.3, contrast=0.2, saturation=0.2),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
from google.colab import drive
drive.mount("/content/drive")

dataset = datasets.ImageFolder(root=root_dir, transform=transform)

train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %%
from google.colab import drive
drive.mount("/content/drive")

train_loader = DataLoader(train_dataset, batch_size=CONFIG.BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=CONFIG.BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=CONFIG.BATCH_SIZE, shuffle=False)

# %%
from google.colab import drive
drive.mount("/content/drive")

model = models.efficientnet_b2(weights=models.EfficientNet_B2_Weights.DEFAULT)
model.classifier = nn.Sequential(
    nn.Dropout(
        p=CONFIG.DROPOUT, 
        inplace=True
        ), 
    nn.Linear(
        model.classifier[1].in_features, 
        CONFIG.N_CLASSES,  
        bias=True
        )
    )
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b2_rwightman-c35c1473.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b2_rwightman-c35c1473.pth
# 100%|██████████| 35.2M/35.2M [00:01<00:00, 24.0MB/s]

# %%
from google.colab import drive
drive.mount("/content/drive")

efficientnet = models.efficientnet_b2(weights=models.EfficientNet_B2_Weights.DEFAULT)

print(f'Default: {efficientnet.classifier}\n\n CustomModel: {model.classifier}')
# Out:
# Default: Sequential(
#   (0): Dropout(p=0.3, inplace=True)
#   (1): Linear(in_features=1408, out_features=1000, bias=True)
# )
#
#  CustomModel: Sequential(
#   (0): Dropout(p=0.3, inplace=True)
#   (1): Linear(in_features=1408, out_features=44, bias=True)
# )

# %%
from google.colab import drive
drive.mount("/content/drive")

summary(model, input_size=(CONFIG.BATCH_SIZE, CONFIG.CHANNELS, CONFIG.IMAGE_HEIGHT, CONFIG.IMAGE_WIDTH))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [16, 44]                  --
# ├─Sequential: 1-1                                       [16, 1408, 7, 7]          --
# │    └─Conv2dNormActivation: 2-1                        [16, 32, 112, 112]        --
# │    │    └─Conv2d: 3-1                                 [16, 32, 112, 112]        864
# │    │    └─BatchNorm2d: 3-2                            [16, 32, 112, 112]        64
# │    │    └─SiLU: 3-3                                   [16, 32, 112, 112]        --
# │    └─Sequential: 2-2                                  [16, 16, 112, 112]        --
# │    │    └─MBConv: 3-4                                 [16, 16, 112, 112]        1,448
# │    │    └─MBConv: 3-5                                 [16, 16, 112, 112]        612
# │    └─Sequential: 2-3                                  [16, 24, 56, 56]          --
# │    │    └─MBConv: 3-6                                 [16, 24, 56, 56]          6,004
# │    │    └─MBConv: 3-7                                 [16, 24, 56, 56]          10,710
# │    │    └─MBConv: 3-8                                 [16, 24, 56, 56]          10,710
# │    └─Sequential: 2-4                                  [16, 48, 28, 28]          --
# │    │    └─MBConv: 3-9                                 [16, 48, 28, 28]          16,518
# │    │    └─MBConv: 3-10                                [16, 48, 28, 28]          43,308
# │    │    └─MBConv: 3-11                                [16, 48, 28, 28]          43,308
# │    └─Sequential: 2-5                                  [16, 88, 14, 14]          --
# │    │    └─MBConv: 3-12                                [16, 88, 14, 14]          50,300
# │    │    └─MBConv: 3-13                                [16, 88, 14, 14]          123,750
# │    │    └─MBConv: 3-14                                [16, 88, 14, 14]          123,750
# │    │    └─MBConv: 3-15                                [16, 88, 14, 14]          123,750
# │    └─Sequential: 2-6                                  [16, 120, 14, 14]         --
# │    │    └─MBConv: 3-16                                [16, 120, 14, 14]         149,158
# │    │    └─MBConv: 3-17                                [16, 120, 14, 14]         237,870
# │    │    └─MBConv: 3-18                                [16, 120, 14, 14]         237,870
# │    │    └─MBConv: 3-19                                [16, 120, 14, 14]         237,870
# │    └─Sequential: 2-7                                  [16, 208, 7, 7]           --
# │    │    └─MBConv: 3-20                                [16, 208, 7, 7]           301,406
# │    │    └─MBConv: 3-21                                [16, 208, 7, 7]           686,868
# │    │    └─MBConv: 3-22                                [16, 208, 7, 7]           686,868
# │    │    └─MBConv: 3-23                                [16, 208, 7, 7]           686,868
# │    │    └─MBConv: 3-24                                [16, 208, 7, 7]           686,868
# │    └─Sequential: 2-8                                  [16, 352, 7, 7]           --
# │    │    └─MBConv: 3-25                                [16, 352, 7, 7]           846,900
# │    │    └─MBConv: 3-26                                [16, 352, 7, 7]           1,888,920
# │    └─Conv2dNormActivation: 2-9                        [16, 1408, 7, 7]          --
# │    │    └─Conv2d: 3-27                                [16, 1408, 7, 7]          495,616
# │    │    └─BatchNorm2d: 3-28                           [16, 1408, 7, 7]          2,816
# │    │    └─SiLU: 3-29                                  [16, 1408, 7, 7]          --
# ├─AdaptiveAvgPool2d: 1-2                                [16, 1408, 1, 1]          --
# ├─Sequential: 1-3                                       [16, 44]                  --
# │    └─Dropout: 2-10                                    [16, 1408]                --
# │    └─Linear: 2-11                                     [16, 44]                  61,996
# =========================================================================================================
# Total params: 7,762,990
# Trainable params: 7,762,990
# Non-trainable params: 0
# Total mult-adds (G): 10.52
# =========================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2508.77
# Params size (MB): 31.05
# Estimated Total Size (MB): 2549.46
# =========================================================================================================

# %%
from google.colab import drive
drive.mount("/content/drive")

class EarlyStopping:
    def __init__(self, patience=0, verbose=False, min_delta=0, path="checkpoint.pth", min_val_acc=0):
        self.patience = patience
        self.verbose = verbose
        self.min_delta = min_delta
        self.path = path
        self.min_val_acc = min_val_acc
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, model, optimizer, scheduler, train_losses, val_losses, train_accuracies, val_accuracies, learning_rate, l2_norm, epochs):
        if val_accuracies[-1] < self.min_val_acc:
            if self.verbose:
                print(f"Validation accuracy {val_accuracies[-1]:.4f} did not reach minimum {self.min_val_acc:.4f}. Not saving.")
            return

        score = val_accuracies[-1]

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(model, optimizer, scheduler, train_losses, val_losses, train_accuracies, val_accuracies, learning_rate, l2_norm, epochs)
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(model, optimizer, scheduler, train_losses, val_losses, train_accuracies, val_accuracies, learning_rate, l2_norm, epochs)
            self.counter = 0

    def save_checkpoint(self, model, optimizer, scheduler, train_losses, val_losses, train_accuracies, val_accuracies, learning_rate, l2_norm, epochs):
        if self.verbose:
            print(f"Validation accuracy improved. Saving model with val_loss {val_losses[-1]:.6f}...")

        training_state = {
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict() if scheduler else None,
            "train_losses": train_losses,
            "val_losses": val_losses,
            "train_accuracies": train_accuracies,
            "val_accuracies": val_accuracies,
            "hyperparameters": {
                "learning_rate": learning_rate,
                "L2 norm": l2_norm,
                "batch_size": 32,
                "epochs": epochs,
            }
        }
        torch.save(training_state, self.path)

# %%
from google.colab import drive
drive.mount("/content/drive")

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=CONFIG.LR, weight_decay=CONFIG.L2)

scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=CONFIG.PATIENCE_SCHEDULER)

# %%
from google.colab import drive
drive.mount("/content/drive")

def train_model(model, data_loader, criterion, optimizer, device):
    model.train()
    train_loss, train_correct, train_total = 0, 0, 0
    for inputs, labels in data_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_correct += (predicted == labels).sum().item()
        train_total += labels.size(0)

    avg_loss = train_loss / len(data_loader)
    train_accuracy = 100 * train_correct / train_total

    return avg_loss, train_accuracy

# %%
from google.colab import drive
drive.mount("/content/drive")

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            val_correct += (predicted == labels).sum().item()
            val_total += labels.size(0)
    
    avg_loss = val_loss / len(data_loader)
    val_accuracy = 100 * val_correct / val_total

    scheduler.step(val_loss)
    current_lr = scheduler.get_last_lr()[0]
    
    return avg_loss, val_accuracy, current_lr

# %%
from google.colab import drive
drive.mount("/content/drive")

train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

early_stopping = EarlyStopping(patience=CONFIG.PATIENCE_EPOCHS, verbose=True, min_val_acc=CONFIG.MIN_VALUE_ACCURACY, path="best_model.pth")

for epoch in range(CONFIG.N_EPOCHS):
    train_loss, train_accuracy = train_model(model, train_loader, criterion, optimizer, CONFIG.DEVICE)
    val_loss, val_accuracy, current_lr = evaluate_model(model, val_loader, criterion, CONFIG.DEVICE)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
    
    print(f"Epoch {epoch+1}/{CONFIG.N_EPOCHS}")
    print(f"Train Loss: {train_loss:.4f} | Train Accuracy: {train_accuracy:.2f}%")
    print(f"Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_accuracy:.2f}%")
    print(f"Learning Rate: {current_lr}")

    early_stopping(model, optimizer, scheduler, train_losses, val_losses, train_accuracies, val_accuracies, CONFIG.LR, CONFIG.L2, CONFIG.N_EPOCHS)
    if early_stopping.early_stop:
        print("Early stopping activated. Stopping training.")
        break
# Out:
# /opt/conda/lib/python3.10/site-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/PIL/TiffImagePlugin.py:900: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 1/50
# Train Loss: 1.0728 | Train Accuracy: 71.37%
# Validation Loss: 0.7325 | Validation Accuracy: 81.16%
# Learning Rate: 0.001
# Validation accuracy improved. Saving model with val_loss 0.732474...
# Epoch 2/50
# Train Loss: 0.5733 | Train Accuracy: 83.81%
# Validation Loss: 0.4244 | Validation Accuracy: 87.69%
# Learning Rate: 0.001
# Validation accuracy improved. Saving model with val_loss 0.424386...
# Epoch 3/50
# Train Loss: 0.4758 | Train Accuracy: 86.39%
# Validation Loss: 0.4914 | Validation Accuracy: 87.99%
# Learning Rate: 0.001
# Validation accuracy improved. Saving model with val_loss 0.491354...
# Epoch 4/50
# Train Loss: 0.4165 | Train Accuracy: 87.96%
# Validation Loss: 0.4288 | Validation Accuracy: 87.13%
# Learning Rate: 0.001
# EarlyStopping counter: 1 out of 10
# Epoch 5/50
# Train Loss: 0.3833 | Train Accuracy: 88.58%
# Validation Loss: 0.3896 | Validation Accuracy: 89.92%
# Learning Rate: 0.001
# Validation accuracy improved. Saving model with val_loss 0.389575...
# Epoch 6/50
# Train Loss: 0.3454 | Train Accuracy: 89.93%
# Validation Loss: 0.4127 | Validation Accuracy: 89.06%
# Learning Rate: 0.001
# EarlyStopping counter: 1 out of 10
# Epoch 7/50
# Train Loss: 0.3301 | Train Accuracy: 90.14%
# Validation Loss: 0.3767 | Validation Accuracy: 90.58%
# Learning Rate: 0.001
# Validation accuracy improved. Saving model with val_loss 0.376668...
# Epoch 8/50
# Train Loss: 0.3215 | Train Accuracy: 90.60%
# Validation Loss: 0.4530 | Validation Accuracy: 88.35%
# Learning Rate: 0.001
# EarlyStopping counter: 1 out of 10
# Epoch 9/50
# Train Loss: 0.2950 | Train Accuracy: 91.13%
# Validation Loss: 0.3559 | Validation Accuracy: 91.44%
# Learning Rate: 0.001
# Validation accuracy improved. Saving model with val_loss 0.355867...
# Epoch 10/50
# Train Loss: 0.2986 | Train Accuracy: 91.47%
# Validation Loss: 0.4124 | Validation Accuracy: 88.80%
# Learning Rate: 0.001
# EarlyStopping counter: 1 out of 10
# Epoch 11/50
# Train Loss: 0.2805 | Train Accuracy: 91.36%
# Validation Loss: 0.3419 | Validation Accuracy: 91.19%
# Learning Rate: 0.001
# EarlyStopping counter: 2 out of 10
# Epoch 12/50
# Train Loss: 0.2845 | Train Accuracy: 91.57%
# Validation Loss: 0.3738 | Validation Accuracy: 91.08%
# Learning Rate: 0.001
# EarlyStopping counter: 3 out of 10
# Epoch 13/50
# Train Loss: 0.2526 | Train Accuracy: 92.22%
# Validation Loss: 0.3577 | Validation Accuracy: 91.39%
# Learning Rate: 0.001
# EarlyStopping counter: 4 out of 10
# Epoch 14/50
# Train Loss: 0.2616 | Train Accuracy: 92.00%
# Validation Loss: 0.3644 | Validation Accuracy: 90.58%
# Learning Rate: 0.001
# EarlyStopping counter: 5 out of 10
# Epoch 15/50
# Train Loss: 0.2413 | Train Accuracy: 92.66%
# Validation Loss: 0.4034 | Validation Accuracy: 90.98%
# Learning Rate: 0.001
# EarlyStopping counter: 6 out of 10
# Epoch 16/50
# Train Loss: 0.2388 | Train Accuracy: 92.60%
# Validation Loss: 0.4265 | Validation Accuracy: 89.61%
# Learning Rate: 0.001
# EarlyStopping counter: 7 out of 10
# Epoch 17/50
# Train Loss: 0.2413 | Train Accuracy: 92.55%
# Validation Loss: 0.4182 | Validation Accuracy: 90.17%
# Learning Rate: 0.0001
# EarlyStopping counter: 8 out of 10
# Epoch 18/50
# Train Loss: 0.1272 | Train Accuracy: 95.76%
# Validation Loss: 0.2745 | Validation Accuracy: 93.52%
# Learning Rate: 0.0001
# Validation accuracy improved. Saving model with val_loss 0.274505...
# Epoch 19/50
# Train Loss: 0.0755 | Train Accuracy: 97.76%
# Validation Loss: 0.2574 | Validation Accuracy: 93.52%
# Learning Rate: 0.0001
# Validation accuracy improved. Saving model with val_loss 0.257384...
# Epoch 20/50
# Train Loss: 0.0647 | Train Accuracy: 97.96%
# Validation Loss: 0.2474 | Validation Accuracy: 94.17%
# Learning Rate: 0.0001
# Validation accuracy improved. Saving model with val_loss 0.247365...
# Epoch 21/50
# Train Loss: 0.0638 | Train Accuracy: 98.12%
# Validation Loss: 0.2499 | Validation Accuracy: 94.43%
# Learning Rate: 0.0001
# Validation accuracy improved. Saving model with val_loss 0.249918...
# Epoch 22/50
# Train Loss: 0.0529 | Train Accuracy: 98.33%
# Validation Loss: 0.2582 | Validation Accuracy: 94.02%
# Learning Rate: 0.0001
# EarlyStopping counter: 1 out of 10
# Epoch 23/50
# Train Loss: 0.0472 | Train Accuracy: 98.50%
# Validation Loss: 0.2489 | Validation Accuracy: 93.52%
# Learning Rate: 0.0001
# EarlyStopping counter: 2 out of 10
# Epoch 24/50
# Train Loss: 0.0398 | Train Accuracy: 98.69%
# Validation Loss: 0.2588 | Validation Accuracy: 94.38%
# Learning Rate: 0.0001
# EarlyStopping counter: 3 out of 10
# Epoch 25/50
# Train Loss: 0.0392 | Train Accuracy: 98.91%
# Validation Loss: 0.2523 | Validation Accuracy: 94.48%
# Learning Rate: 0.0001
# Validation accuracy improved. Saving model with val_loss 0.252345...
# Epoch 26/50
# Train Loss: 0.0381 | Train Accuracy: 98.83%
# Validation Loss: 0.2954 | Validation Accuracy: 93.57%
# Learning Rate: 1e-05
# EarlyStopping counter: 1 out of 10
# Epoch 27/50
# Train Loss: 0.0326 | Train Accuracy: 99.01%
# Validation Loss: 0.2688 | Validation Accuracy: 93.82%
# Learning Rate: 1e-05
# EarlyStopping counter: 2 out of 10
# Epoch 28/50
# Train Loss: 0.0315 | Train Accuracy: 99.07%
# Validation Loss: 0.2535 | Validation Accuracy: 94.53%
# Learning Rate: 1e-05
# Validation accuracy improved. Saving model with val_loss 0.253509...
# Epoch 29/50
# Train Loss: 0.0262 | Train Accuracy: 99.29%
# Validation Loss: 0.2597 | Validation Accuracy: 94.38%
# Learning Rate: 1e-05
# EarlyStopping counter: 1 out of 10
# Epoch 30/50
# Train Loss: 0.0258 | Train Accuracy: 99.25%
# Validation Loss: 0.2602 | Validation Accuracy: 94.48%
# Learning Rate: 1e-05
# EarlyStopping counter: 2 out of 10
# Epoch 31/50
# Train Loss: 0.0275 | Train Accuracy: 99.12%
# Validation Loss: 0.2468 | Validation Accuracy: 94.22%
# Learning Rate: 1e-05
# EarlyStopping counter: 3 out of 10
# Epoch 32/50
# Train Loss: 0.0270 | Train Accuracy: 99.23%
# Validation Loss: 0.2515 | Validation Accuracy: 94.48%
# Learning Rate: 1e-05
# EarlyStopping counter: 4 out of 10
# Epoch 33/50
# Train Loss: 0.0272 | Train Accuracy: 99.07%
# Validation Loss: 0.2616 | Validation Accuracy: 94.22%
# Learning Rate: 1e-05
# EarlyStopping counter: 5 out of 10
# Epoch 34/50
# Train Loss: 0.0272 | Train Accuracy: 99.07%
# Validation Loss: 0.2504 | Validation Accuracy: 94.53%
# Learning Rate: 1e-05
# Validation accuracy improved. Saving model with val_loss 0.250447...
# Epoch 35/50
# Train Loss: 0.0237 | Train Accuracy: 99.34%
# Validation Loss: 0.2588 | Validation Accuracy: 94.53%
# Learning Rate: 1e-05
# Validation accuracy improved. Saving model with val_loss 0.258758...
# Epoch 36/50
# Train Loss: 0.0233 | Train Accuracy: 99.40%
# Validation Loss: 0.2542 | Validation Accuracy: 94.33%
# Learning Rate: 1e-05
# EarlyStopping counter: 1 out of 10
# Epoch 37/50
# Train Loss: 0.0264 | Train Accuracy: 99.19%
# Validation Loss: 0.2594 | Validation Accuracy: 94.17%
# Learning Rate: 1.0000000000000002e-06
# EarlyStopping counter: 2 out of 10
# Epoch 38/50
# Train Loss: 0.0235 | Train Accuracy: 99.31%
# Validation Loss: 0.2552 | Validation Accuracy: 94.22%
# Learning Rate: 1.0000000000000002e-06
# EarlyStopping counter: 3 out of 10
# Epoch 39/50
# Train Loss: 0.0248 | Train Accuracy: 99.22%
# Validation Loss: 0.2564 | Validation Accuracy: 94.53%
# Learning Rate: 1.0000000000000002e-06
# Validation accuracy improved. Saving model with val_loss 0.256413...
# Epoch 40/50
# Train Loss: 0.0219 | Train Accuracy: 99.48%
# Validation Loss: 0.2568 | Validation Accuracy: 94.28%
# Learning Rate: 1.0000000000000002e-06
# EarlyStopping counter: 1 out of 10
# Epoch 41/50
# Train Loss: 0.0260 | Train Accuracy: 99.28%
# Validation Loss: 0.2580 | Validation Accuracy: 94.43%
# Learning Rate: 1.0000000000000002e-06
# EarlyStopping counter: 2 out of 10
# Epoch 42/50
# Train Loss: 0.0246 | Train Accuracy: 99.23%
# Validation Loss: 0.2577 | Validation Accuracy: 94.38%
# Learning Rate: 1.0000000000000002e-06
# EarlyStopping counter: 3 out of 10
# Epoch 43/50
# Train Loss: 0.0235 | Train Accuracy: 99.26%
# Validation Loss: 0.2658 | Validation Accuracy: 94.02%
# Learning Rate: 1.0000000000000002e-07
# EarlyStopping counter: 4 out of 10
# Epoch 44/50
# Train Loss: 0.0250 | Train Accuracy: 99.23%
# Validation Loss: 0.2618 | Validation Accuracy: 94.02%
# Learning Rate: 1.0000000000000002e-07
# EarlyStopping counter: 5 out of 10
# Epoch 45/50
# Train Loss: 0.0246 | Train Accuracy: 99.11%
# Validation Loss: 0.2473 | Validation Accuracy: 94.63%
# Learning Rate: 1.0000000000000002e-07
# Validation accuracy improved. Saving model with val_loss 0.247313...
# Epoch 46/50
# Train Loss: 0.0246 | Train Accuracy: 99.29%
# Validation Loss: 0.2786 | Validation Accuracy: 93.77%
# Learning Rate: 1.0000000000000002e-07
# EarlyStopping counter: 1 out of 10
# Epoch 47/50
# Train Loss: 0.0225 | Train Accuracy: 99.42%
# Validation Loss: 0.2628 | Validation Accuracy: 94.17%
# Learning Rate: 1.0000000000000002e-07
# EarlyStopping counter: 2 out of 10
# Epoch 48/50
# Train Loss: 0.0219 | Train Accuracy: 99.44%
# Validation Loss: 0.2554 | Validation Accuracy: 94.28%
# Learning Rate: 1.0000000000000002e-07
# EarlyStopping counter: 3 out of 10
# Epoch 49/50
# Train Loss: 0.0232 | Train Accuracy: 99.35%
# Validation Loss: 0.2466 | Validation Accuracy: 94.58%
# Learning Rate: 1.0000000000000002e-07
# EarlyStopping counter: 4 out of 10
# Epoch 50/50
# Train Loss: 0.0227 | Train Accuracy: 99.34%
# Validation Loss: 0.2551 | Validation Accuracy: 94.88%
# Learning Rate: 1.0000000000000002e-07
# Validation accuracy improved. Saving model with val_loss 0.255075...

# %%
from google.colab import drive
drive.mount("/content/drive")
